# %% [markdown]
# # **Tugas Clustering**
#
# Kresna Adhi Pramana - 05111840000072 - Data Mining A

# %%
# Import library
from google.colab import drive
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import cdist
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Import dataset
drive.mount('/content/drive')

data_path = r'drive/My Drive/Dataset/Credit Card/data.csv'
dataset = pd.read_csv(data_path)
# Out:
# Mounted at /content/drive

# %%
# Drop cust_id column
dataset.drop('CUST_ID', axis=1, inplace=True)

dataset.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0    40.900749           0.818182  ...          0.000000      12
# 1  3202.467416           0.909091  ...          0.222222      12
# 2  2495.148862           1.000000  ...          0.000000      12
# 3  1666.670542           0.636364  ...          0.000000      12
# 4   817.714335           1.000000  ...          0.000000      12
#
# [5 rows x 17 columns]

# %%
# Check null values
dataset.isnull().sum().sort_values(ascending=False)
# Out:
# MINIMUM_PAYMENTS                    313
# CREDIT_LIMIT                          1
# TENURE                                0
# PURCHASES_FREQUENCY                   0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# ONEOFF_PURCHASES_FREQUENCY            0
# PRC_FULL_PAYMENT                      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# PAYMENTS                              0
# BALANCE                               0
# dtype: int64

# %%
# Replace null values
dataset.loc[(dataset['MINIMUM_PAYMENTS'].isnull()==True), 'MINIMUM_PAYMENTS'] = dataset['MINIMUM_PAYMENTS'].mean()
dataset.loc[(dataset['CREDIT_LIMIT'].isnull()==True), 'CREDIT_LIMIT'] = dataset['CREDIT_LIMIT'].mean()

# Check null values
dataset.isnull().sum().sort_values(ascending=False)
# Out:
# TENURE                              0
# ONEOFF_PURCHASES_FREQUENCY          0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# PRC_FULL_PAYMENT                    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# BALANCE                             0
# dtype: int64

# %%
# Pre-processing
scaler = StandardScaler() 
scaled_data = scaler.fit_transform(dataset) 

df = pd.DataFrame(scaled_data, columns=dataset.columns)
df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT   TENURE
# 0 -0.731989          -0.249434  ...         -0.525551  0.36068
# 1  0.786961           0.134325  ...          0.234227  0.36068
# 2  0.447135           0.518084  ...         -0.525551  0.36068
# 3  0.049099          -1.016953  ...         -0.525551  0.36068
# 4 -0.358775           0.518084  ...         -0.525551  0.36068
#
# [5 rows x 17 columns]

# %%
# Dendogram visualization
plt.figure(figsize=(15, 10))
dendrogram(linkage(df, method="ward"), leaf_rotation=90, p=5, color_threshold=20, leaf_font_size=10, truncate_mode='level')

plt.show()

# %%
# Find n clusters using silhoutte scores (Agglomerative Clustering)
silhouette_scores = [] 

for n_cluster in range(2, 10):
    silhouette_scores.append( 
        silhouette_score(df, AgglomerativeClustering(n_clusters=n_cluster).fit_predict(df))) 

plt.bar(range(2, 10), silhouette_scores) 
plt.xlabel('Number of clusters', fontsize=10) 
plt.ylabel('Silhouette Score', fontsize=10) 
plt.show()

# %%
# Agglomerative clustering - cluster = 3
agglo = AgglomerativeClustering(n_clusters=3)
agglo.fit(df)
agglo_labels = agglo.labels_
res_agglo = pd.concat([df, pd.DataFrame({'cluster':agglo_labels})], axis=1)
res_agglo.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ...  PRC_FULL_PAYMENT   TENURE  cluster
# 0 -0.731989          -0.249434  -0.424900  ...         -0.525551  0.36068        1
# 1  0.786961           0.134325  -0.469552  ...          0.234227  0.36068        2
# 2  0.447135           0.518084  -0.107668  ...         -0.525551  0.36068        0
# 3  0.049099          -1.016953   0.232058  ...         -0.525551  0.36068        1
# 4 -0.358775           0.518084  -0.462063  ...         -0.525551  0.36068        1
#
# [5 rows x 18 columns]

# %%
# Result visualization (Agglomerative Clustering)
for i in res_agglo:
    grid = sns.FacetGrid(res_agglo, col='cluster')
    grid.map(plt.hist, i)

# %%
# K-means determine K
distortions = []

for k in range(1, 10):
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    distortions.append(sum(np.min(cdist(df, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / df.shape[0])

# Plot the elbow
plt.plot(range(1, 10), distortions, 'bx-')
plt.xlabel('Value of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal K (Distortion)')

plt.show()

# %%
# K-means determine K
inertias = []

for k in range(1, 10):
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df)
    inertias.append(kmeanModel.inertia_)

# Plot the elbow
plt.plot(range(1, 10), inertias, 'bx-')
plt.xlabel('Value of K')
plt.ylabel('Inertia')
plt.title('The Elbow Method showing the optimal K (Inertia)')

plt.show()

# %%
# Find n clusters using silhoutte scores (K-means Clustering)
silhouette_scores = [] 

for n_cluster in range(2, 10):
    silhouette_scores.append( 
        silhouette_score(df, KMeans(n_clusters=n_cluster).fit_predict(df))) 

plt.bar(range(2, 10), silhouette_scores) 
plt.xlabel('Number of clusters', fontsize=10) 
plt.ylabel('Silhouette Score', fontsize=10) 
plt.show()

# %%
# K-means clustering - cluster = 3
kmeans = KMeans(n_clusters=3)
kmeans.fit(df)
kmeans_labels = kmeans.labels_
res_kmeans = pd.concat([df, pd.DataFrame({'cluster':kmeans_labels})], axis=1)
res_kmeans.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ...  PRC_FULL_PAYMENT   TENURE  cluster
# 0 -0.731989          -0.249434  -0.424900  ...         -0.525551  0.36068        0
# 1  0.786961           0.134325  -0.469552  ...          0.234227  0.36068        2
# 2  0.447135           0.518084  -0.107668  ...         -0.525551  0.36068        0
# 3  0.049099          -1.016953   0.232058  ...         -0.525551  0.36068        0
# 4 -0.358775           0.518084  -0.462063  ...         -0.525551  0.36068        0
#
# [5 rows x 18 columns]

# %%
# Result visualization (K-Means Clustering)
for i in res_kmeans:
    grid = sns.FacetGrid(res_kmeans, col='cluster')
    grid.map(plt.hist, i)
